# %% [markdown]
# # Exercise 1: Prime Numbers

# %% [markdown]
# - Write a Python program that checks whether a given number is prime or not.
# - A prime number is a natural number greater than 1 that has no positive divisors other than 1 and itself.

# %%
def is_prime(num):
    if num <= 1:
        return False
    # Only need to check up to the square root of the number
    for i in range(2, int(num ** 0.5) + 1):
        if num % i == 0:
            return False
    return True

# %%
number = int(input("Enter a number: "))
# Out:
# Enter a number:  10

# %%
if is_prime(number):
    print(f"{number} is a prime number.")
else:
    print(f"{number} is not a prime number.")
# Out:
# 10 is not a prime number.

# %%
number = int(input("Enter a number: "))
# Out:
# Enter a number:  3

# %%
if is_prime(number):
    print(f"{number} is a prime number.")
else:
    print(f"{number} is not a prime number.")
# Out:
# 3 is a prime number.

# %% [markdown]
# # Exercise 2: Product of Random Numbers

# %%
''' Develop a Python program that generates two random numbers and asks the user to enter the 
product of these numbers. The program should then check if 
the user's answer is correct and display an appropriate message. '''
# Out:
# " Develop a Python program that generates two random numbers and asks the user to enter the \nproduct of these numbers. The program should then check if \nthe user's answer is correct and display an appropriate message. "

# %%
import random

# %%
num1=random.randint(1,10)
num2=random.randint(1,10)
if int(input(f"what is the product of {num1} and {num2} = ")) == num1*num2:
    print("you are correct")
else:
    product=num1*num2
    print(f"you are wrong, the correct product is {product}")
# Out:
# what is the product of 9 and 5 =  45
# you are correct

# %% [markdown]
# # Exercise 3: Squares of Even/Odd Numbers

# %% [markdown]
# Create a Python script that prints the squares of all even or odd numbers within the range of 100 to 200. Choose either even or odd numbers and document your choice in the code.

# %%
# will try to proint of squares of all even no

# %%
for i in range(100,201):
    if i%2==0:
        print(f"the square of {i} = ",i**2)
    else:
        print(f"{i} not an even no  ")
        continue
# Out:
# the square of 100 =  10000
# 101 not an even no
# the square of 102 =  10404
# 103 not an even no
# the square of 104 =  10816
# 105 not an even no
# the square of 106 =  11236
# 107 not an even no
# the square of 108 =  11664
# 109 not an even no
# the square of 110 =  12100
# 111 not an even no
# the square of 112 =  12544
# 113 not an even no
# the square of 114 =  12996
# 115 not an even no
# the square of 116 =  13456
# 117 not an even no
# the square of 118 =  13924
# 119 not an even no
# the square of 120 =  14400
# 121 not an even no
# the square of 122 =  14884
# 123 not an even no
# the square of 124 =  15376
# 125 not an even no
# the square of 126 =  15876
# 127 not an even no
# the square of 128 =  16384
# 129 not an even no
# the square of 130 =  16900
# 131 not an even no
# the square of 132 =  17424
# 133 not an even no
# the square of 134 =  17956
# 135 not an even no
# the square of 136 =  18496
# 137 not an even no
# the square of 138 =  19044
# 139 not an even no
# ...

# %% [markdown]
# # Exercise 4: Word counter

# %% [markdown]
# write a program to count the number of words in a given text.

# %%
input_text = "This is a sample text. This text will be used to demonstrate the word counter."

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
vectorizer=CountVectorizer(ngram_range=(1, 1))

# %%
# vectorizer.fit_transform([input_text]) - not possible as it expects lists of texts
vectorizer.fit_transform([input_text])
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 12 stored elements and shape (1, 12)>

# %%
vectorizer.vocabulary_
# Out:
# {'this': 7,
#  'is': 3,
#  'sample': 4,
#  'text': 5,
#  'will': 10,
#  'be': 0,
#  'used': 9,
#  'to': 8,
#  'demonstrate': 2,
#  'the': 6,
#  'word': 11,
#  'counter': 1}

# %%
''' words_duplicate_count=[]
words=input_text.split();
#print(words)
for i in words:
    if i in words_duplicate_count:
        print(1)
    else:
        words_duplicate_count.append(i) '''


words = input_text.split()
freq = {}

for word in words:
    freq[word] = freq.get(word, 0) + 1

print(freq)
# Out:
# {'This': 2, 'is': 1, 'a': 1, 'sample': 1, 'text.': 1, 'text': 1, 'will': 1, 'be': 1, 'used': 1, 'to': 1, 'demonstrate': 1, 'the': 1, 'word': 1, 'counter.': 1}

# %% [markdown]
# # Exercise 5: Check for Palindrome

# %% [markdown]
# Write a Python function called is_palindrome that takes a string as input and returns True if the string is a palindrome, and False otherwise. A palindrome is a word, phrase, number, or other sequence of characters that reads the same forward and backward, ignoring spaces, punctuation, and capitalization.

# %%
pal='mom'

# %%
print(pal[::-1])
# Out:
# mom

# %%
pal1='sister'

# %%
 print(pal1[::-1])
# Out:
# retsis

# %%
import re

# %%
def is_paliandrome(word):
    word=re.sub(r'[^a-zA-Z0-9]', '', word).lower()
    return word==word[::-1]

# %%
is_paliandrome('mom')
# Out:
# True

# %%
is_paliandrome('sister')
# Out:
# False

# %%
is_paliandrome('mom/#')
# Out:
# True

# %%
is_paliandrome('Mom/#')
# Out:
# True
