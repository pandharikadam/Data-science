# %% [markdown]
# # Holt-Winters Methods

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Load the dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../../datasets/airline_passengers.csv',index_col='Month',parse_dates=True)
df
# Out:
#             Thousands of Passengers
# Month
# 1949-01-01                      112
# 1949-02-01                      118
# 1949-03-01                      132
# 1949-04-01                      129
# 1949-05-01                      121
# ...                             ...
# 1960-08-01                      606
# 1960-09-01                      508
# 1960-10-01                      461
# 1960-11-01                      390
# 1960-12-01                      432
#
# [144 rows x 1 columns]

# %%
df.fillna(method='ffill')
# Out:
#             Thousands of Passengers
# Month
# 1949-01-01                      112
# 1949-02-01                      118
# 1949-03-01                      132
# 1949-04-01                      129
# 1949-05-01                      121
# ...                             ...
# 1960-08-01                      606
# 1960-09-01                      508
# 1960-10-01                      461
# 1960-11-01                      390
# 1960-12-01                      432
#
# [144 rows x 1 columns]

# %%
#df.dropna(inplace=True)

# %%
df.index
# Out:
# DatetimeIndex(['1949-01-01', '1949-02-01', '1949-03-01', '1949-04-01',
#                '1949-05-01', '1949-06-01', '1949-07-01', '1949-08-01',
#                '1949-09-01', '1949-10-01',
#                ...
#                '1960-03-01', '1960-04-01', '1960-05-01', '1960-06-01',
#                '1960-07-01', '1960-08-01', '1960-09-01', '1960-10-01',
#                '1960-11-01', '1960-12-01'],
#               dtype='datetime64[ns]', name='Month', length=144, freq=None)

# %%
df.index.freq

# %% [markdown]
# ### Setting a DatetimeIndex Frequency

# %%
df.index.freq = 'MS'
df.index
# Out:
# DatetimeIndex(['1949-01-01', '1949-02-01', '1949-03-01', '1949-04-01',
#                '1949-05-01', '1949-06-01', '1949-07-01', '1949-08-01',
#                '1949-09-01', '1949-10-01',
#                ...
#                '1960-03-01', '1960-04-01', '1960-05-01', '1960-06-01',
#                '1960-07-01', '1960-08-01', '1960-09-01', '1960-10-01',
#                '1960-11-01', '1960-12-01'],
#               dtype='datetime64[ns]', name='Month', length=144, freq='MS')

# %%
df.head()

# %%
df['Thousands of Passengers'].plot()
plt.show()

# %% [markdown]
# ___
# ## Simple Exponential Smoothing

# %%
from statsmodels.tsa.holtwinters import SimpleExpSmoothing
alpha = 0.15

# %%
model_ses12=SimpleExpSmoothing(df['Thousands of Passengers'])
fitted_model= model_ses12.fit(smoothing_level=alpha,optimized=False)
fitted_model.fittedvalues
# Out:
# Month
# 1949-01-01    112.000000
# 1949-02-01    112.000000
# 1949-03-01    112.900000
# 1949-04-01    115.765000
# 1949-05-01    117.750250
#                  ...
# 1960-08-01    473.417458
# 1960-09-01    493.304839
# 1960-10-01    495.509113
# 1960-11-01    490.332746
# 1960-12-01    475.282834
# Freq: MS, Length: 144, dtype: float64

# %%
df['SES12'] = fitted_model.fittedvalues.shift(-1)
df.head()
# Out:
#             Thousands of Passengers       SES12
# Month
# 1949-01-01                      112  112.000000
# 1949-02-01                      118  112.900000
# 1949-03-01                      132  115.765000
# 1949-04-01                      129  117.750250
# 1949-05-01                      121  118.237712

# %% [markdown]
# ___
# ## Double Exponential Smoothing

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing

mod_add12 = ExponentialSmoothing(df['Thousands of Passengers'], trend='add')
fitted_model= mod_add12.fit()
df['DESadd12'] = fitted_model.fittedvalues.shift(-1)
df.head()
# Out:
#             Thousands of Passengers       SES12    DESadd12
# Month
# 1949-01-01                      112  112.000000  114.102394
# 1949-02-01                      118  112.900000  120.040657
# 1949-03-01                      132  115.765000  134.001539
# 1949-04-01                      129  117.750250  131.085845
# 1949-05-01                      121  118.237712  123.110263

# %%
df[['Thousands of Passengers','SES12','DESadd12']].iloc[:24].plot(figsize=(8,4));

# %%
df['DESmul12'] = ExponentialSmoothing(df['Thousands of Passengers'], trend='mul').fit().fittedvalues.shift(-1)
df.head()
# Out:
#             Thousands of Passengers       SES12    DESadd12    DESmul12
# Month
# 1949-01-01                      112  112.000000  114.102394  113.990701
# 1949-02-01                      118  112.900000  120.040657  120.031669
# 1949-03-01                      132  115.765000  134.001539  134.235979
# 1949-04-01                      129  117.750250  131.085845  131.270786
# 1949-05-01                      121  118.237712  123.110263  123.156267

# %%
df[['Thousands of Passengers','DESadd12','DESmul12']].iloc[:24].plot(figsize=(12,6));

# %% [markdown]
# ___
# ## Triple Exponential Smoothing

# %%
df['TESadd12'] = ExponentialSmoothing(df['Thousands of Passengers'],trend='add',seasonal='add',seasonal_periods=12).fit().fittedvalues
df.head()
# Out:
#             Thousands of Passengers       SES12    DESadd12    DESmul12  \
# Month
# 1949-01-01                      112  112.000000  114.102394  113.990701
# 1949-02-01                      118  112.900000  120.040657  120.031669
# 1949-03-01                      132  115.765000  134.001539  134.235979
# 1949-04-01                      129  117.750250  131.085845  131.270786
# 1949-05-01                      121  118.237712  123.110263  123.156267
#
#               TESadd12
# Month
# 1949-01-01  112.000426
# 1949-02-01  120.166896
# 1949-03-01  134.699678
# 1949-04-01  131.377132
# 1949-05-01  124.630340

# %%
df['TESmul12'] = ExponentialSmoothing(df['Thousands of Passengers'],trend='mul',seasonal='mul',seasonal_periods=12).fit().fittedvalues
df.head()
# Out:
#             Thousands of Passengers       SES12    DESadd12    DESmul12  \
# Month
# 1949-01-01                      112  112.000000  114.102394  113.990701
# 1949-02-01                      118  112.900000  120.040657  120.031669
# 1949-03-01                      132  115.765000  134.001539  134.235979
# 1949-04-01                      129  117.750250  131.085845  131.270786
# 1949-05-01                      121  118.237712  123.110263  123.156267
#
#               TESadd12    TESmul12
# Month
# 1949-01-01  112.000426  111.590116
# 1949-02-01  120.166896  118.839628
# 1949-03-01  134.699678  133.334609
# 1949-04-01  131.377132  127.896905
# 1949-05-01  124.630340  120.975952

# %%
df[['Thousands of Passengers','TESadd12','TESmul12']].plot(figsize=(12,6))
# Out:
# <Axes: xlabel='Month'>

# %%
df[['Thousands of Passengers','TESadd12','TESmul12']].iloc[:24].plot(figsize=(12,6))
# Out:
# <Axes: xlabel='Month'>
