# %%
CHI-SQUARE TEST
Association between Device Type and Customer Satisfaction
Background:
Mizzare Corporation has collected data on customer satisfaction levels for two types of smart home devices: Smart Thermostats and Smart Lights. They want to determine if there's a significant association between the type of device purchased and the customer's satisfaction level.
Data Provided:
The data is summarized in a contingency table showing the counts of customers in each satisfaction level for both types of devices:
Satisfaction	Smart Thermostat	Smart Light	Total
Very Satisfied	50	70	120
Satisfied	80	100	180
Neutral	60	90	150
Unsatisfied	30	50	80
Very Unsatisfied	20	50	70
Total	240	360	600
Objective:
To use the Chi-Square test for independence to determine if there's a significant association between the type of smart home device purchased (Smart Thermostats vs. Smart Lights) and the customer satisfaction level.
Assignment Tasks:
1. State the Hypotheses:
2. Compute the Chi-Square Statistic:
3. Determine the Critical Value:
Using the significance level (alpha) of 0.05 and the degrees of freedom (which is the number of categories minus 1)
4. Make a Decision:
Compare the Chi-Square statistic with the critical value to decide whether to reject the null hypothesis.
Submission Guidelines:
•	Provide a detailed report of your analysis, including each step outlined in the assignment tasks in a python file.
•	Include all calculations, the Chi-Square statistic, the critical value, and your conclusion.
# Out:
#   Cell In[4], line 15
#     To use the Chi-Square test for independence to determine if there's a significant association between the type of smart home device purchased (Smart Thermostats vs. Smart Lights) and the customer satisfaction level.
#                                                                      ^
# SyntaxError: unterminated string literal (detected at line 15)

# %% [markdown]
# - H0 - There is no association between customer satisfaction and devices
# - alpha = 0.05
# - DF = (r-1)(c-1)= 4

# %%
import numpy as np
from scipy.stats import chi2_contingency, chi2

# %%
# first create observed frequency table
observed = np.array([  [50, 70],
    [80, 100],
    [60, 90],
    [30, 50],
    [20, 50]])
# we can create dataframe also rather than array

# %%
type(observed)
# Out:
# numpy.ndarray

# %%
# Perform Chi-Square Test
chi2_stat, p_val, dof, expected = chi2_contingency(observed)

# %%
chi2_stat, p_val, dof, expected
# Out:
# (5.638227513227513,
#  0.22784371130697179,
#  4,
#  array([[ 48.,  72.],
#         [ 72., 108.],
#         [ 60.,  90.],
#         [ 32.,  48.],
#         [ 28.,  42.]]))

# %%
# Critical value for alpha = 0.05 and dof = (rows-1)*(columns-1) = 4
alpha = 0.05
critical_value = chi2.ppf(1 - alpha, df=dof)
# the same can be checked in chisquare table for the value of df=4 and alpha=0.05

# %%
critical_value
# Out:
# 9.487729036781154

# %%
if chi2_stat > critical_value:
    print("Reject the null hypothesis: There is a significant association.")
else:
    print("Fail to reject the null hypothesis: No significant association.")
# Out:
# Fail to reject the null hypothesis: No significant association.

# %%
# Also we can decide based on below as well.

# %%
if p_val < alpha:
    print("Reject the null hypothesis: There is a significant association.")
else:
    print("Fail to reject the null hypothesis: No significant association.")
# Out:
# Fail to reject the null hypothesis: No significant association.
