# %% [markdown]
# ### SEQUENCES

# %%
print('hellow')
# Out:
# hellow

# %%
print('kdfjajf')
# Out:
# kdfjajf

# %% [markdown]
# Variables

# %%
x=10

# %%
x
# Out:
# 10

# %%
print(x)
# Out:
# 10

# %%
type(x)
# Out:
# int

# %%
x='ga'

# %%
type(x)
# Out:
# str

# %%
x=10.1

# %%
x
# Out:
# 10.1

# %%
type(x) #
# Out:
# float

# %%
y=10.4546544
print(y)
# Out:
# 10.4546544

# %%
with = 25
# Out:
#   Cell In[33], line 1
#     with = 25
#          ^
# SyntaxError: invalid syntax

# %%
x=10
print('the value of x is : ',x)
# Out:
# the value of x is :  10

# %%
# F - string
age=20
name='sam'
print(f'{name} is {age} years old')
# Out:
# sam is 20 years old

# %% [markdown]
# ### Floor

# %%
x=10
y=3
print(x//y)
# Out:
# 3

# %%
import math
math.floor(3.4)
# Out:
# 3

# %%
math.floor(3.68)
# Out:
# 3

# %%
math.floor(3.9)
# Out:
# 3

# %%
x=5

# %%
x=x+6
x
# Out:
# 41

# %%
x+=6
x
# Out:
# 77

# %% [markdown]
# # DAY 2

# %% [markdown]
# ## Arithemetic operations

# %% [markdown]
# ### AND OR NOT

# %% [markdown]
# # 2.1 COLLECTIONS

# %% [markdown]
# ## 2.1.1 LIST

# %%
list1=[1,2,2,5,6]
list1
# Out:
# [1, 2, 2, 5, 6]

# %%
#\disply elements based on index
print('fisrt element : ',list1[0])
print('forth element : ',list1[3])
print('elements from 1 to 3rd : ',list1[0:3])
print('elements from 4th psition till last : ',list1[3:])
print('elements from lst postion : ',list1[-1])
# Out:
# fisrt element :  1
# forth element :  5
# elements from 1 to 3rd :  [1, 2, 2]
# elements from 4th psition till last :  [5, 6]
# elements from lst postion :  6

# %%
list2=[1,2,'hello',[10,20,30,40,50,60],('A','b','c','d','e')]
print('first element : ',list2[0])
print('second element : ',list2[1])
print('third element : ',list2[2])
print('fourth element : ',list2[3])
print('fifth element : ',list2[4])
print('fourth elemnts first element : ',list2[3][0])
print('fourth elemnts second  element : ',list2[3][1])
print('fourth elemnts third  element : ',list2[3][2])
print('fourth elemnts fourth  element : ',list2[3][3])
print('fourth elemnts fifth  element : ',list2[3][4])
print('fourth elemnts second to 3rd  element : ',list2[3][1:3])
print('fourth elemnts second to 4th  element : ',list2[3][1:4])
print('fifth elemnts second element : ',list2[4][1])
print('fifth elemnts second to third element : ',list2[4][1:3])
print('fifth elemnts second to third element : ',list2[4][1:4])
# Out:
# first element :  1
# second element :  2
# third element :  hello
# fourth element :  [10, 20, 30, 40, 50, 60]
# fifth element :  ('A', 'b', 'c', 'd', 'e')
# fourth elemnts first element :  10
# fourth elemnts second  element :  20
# fourth elemnts third  element :  30
# fourth elemnts fourth  element :  40
# fourth elemnts fifth  element :  50
# fourth elemnts second to 3rd  element :  [20, 30]
# fourth elemnts second to 4th  element :  [20, 30, 40]
# fifth elemnts second element :  b
# fifth elemnts second to third element :  ('b', 'c')
# fifth elemnts second to third element :  ('b', 'c', 'd')

# %% [markdown]
# ## 2.2.2 TUPLE

# %%
tuple=(1,2,3,4,5)
tuple
# Out:
# (1, 2, 3, 4, 5)

# %%
tuple[1:3]
# Out:
# (2, 3)

# %%
string='pyhton3.0'
string
print(string[6])
# Out:
# 3

# %%
y=print(string[6])
y
type(y)
# Out:
# 3
# NoneType

# %%
type(x)
# Out:
# int
